# %%
# !pip install ultralytics tensorflow
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.4.68-py3-none-any.whl.metadata (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 1.5 MB/s eta 0:00:00
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.12/dist-packages (2.20.0)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (4.13.0.92)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.16.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.11.0+cu128)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (0.26.0+cu128)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: polars>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.35.2)
# Requirement already satisfied: nvidia-ml-py>=12.0.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (13.610.43)
# Collecting ultralytics-thop>=2.0.18 (from ultralytics)
#   Downloading ultralytics_thop-2.0.20-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow) (26.2)
# Requirement already satisfied: protobuf>=5.28.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (5.29.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.2.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.81.0)
# Requirement already satisfied: tensorboard~=2.20.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.13.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.16.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow) (0.47.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow) (0.19.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: polars-runtime-32==1.35.2 in /usr/local/lib/python3.12/dist-packages (from polars>=0.20.0->ultralytics) (1.35.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2026.5.20)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow) (3.10.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow) (3.1.8)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.29.2)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings<13,>=12.9.4->torch>=1.8.0->ultralytics) (1.5.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.10.0->tensorflow) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.10.0->tensorflow) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.2)
# Downloading ultralytics-8.4.68-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 30.2 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.20-py3-none-any.whl (28 kB)
# Installing collected packages: ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.4.68 ultralytics-thop-2.0.20

# %%
# from ultralytics import YOLO

# model = YOLO('/content/best.pt')

# print("Model loaded!")

from ultralytics import YOLO

model = YOLO('/content/best.pt')

print("Model Loaded")
# Out:
# Model Loaded

# %%
model.export(format='tflite', imgsz=640)
print("Export Complete")
# Out:
# Ultralytics 8.4.68 🚀 Python-3.12.13 torch-2.11.0+cu128 CPU (Intel Xeon CPU @ 2.00GHz)
# 💡 ProTip: Export to OpenVINO format for best performance on Intel hardware. Learn more at https://docs.ultralytics.com/integrations/openvino/
# Model summary (fused): 73 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
#
# PyTorch: starting from '/content/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 5, 8400) (6.0 MB)
# requirements: Ultralytics requirements ['onnx>=1.12.0,<2.0.0', 'onnxruntime', 'onnxslim>=0.1.82'] not found, attempting AutoUpdate...
# Using Python 3.12.13 environment at: /usr
# Resolved 12 packages in 298ms
# Prepared 4 packages in 1.76s
# Installed 4 packages in 253ms
#  + colorama==0.4.6
#  + onnx==1.22.0
#  + onnxruntime==1.27.0
#  + onnxslim==0.1.94
#
# requirements: AutoUpdate success ✅ 2.9s
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
#
#
# ONNX: starting export with onnx 1.22.0 opset 20...
# /usr/local/lib/python3.12/dist-packages/ultralytics/utils/export/tensorflow.py:42: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if self.format != "imx" and (self.dynamic or self.shape != shape):
# /usr/local/lib/python3.12/dist-packages/ultralytics/utils/export/tensorflow.py:46: TracerWarning: torch.tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   grid_size = torch.tensor([grid_w, grid_h, grid_w, grid_h], device=boxes.device).reshape(1, 4, 1)
# ONNX: slimming with onnxslim 0.1.94...
# ONNX: export success ✅ 4.5s, saved as '/content/best.onnx' (11.8 MB)
# requirements: Ultralytics requirement ['onnx2tf>=1.26.3,<1.29.0'] not found, attempting AutoUpdate...
# Using Python 3.12.13 environment at: /usr
# Resolved 1 package in 159ms
# Prepared 1 package in 61ms
# Installed 1 package in 6ms
#  + onnx2tf==1.28.8
#
# requirements: AutoUpdate success ✅ 0.4s
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
#
# requirements: Ultralytics requirements ['tf_keras<=2.19.0', 'sng4onnx>=1.0.1', 'onnx_graphsurgeon>=0.3.26', 'ai-edge-litert>=1.2.0'] not found, attempting AutoUpdate...
# Using Python 3.12.13 environment at: /usr
# Resolved 44 packages in 4.01s
# Prepared 7 packages in 18.15s
# Uninstalled 3 packages in 1.20s
# Installed 7 packages in 454ms
#  + ai-edge-litert==2.1.5
#  + backports-strenum==1.3.1
#  + onnx-graphsurgeon==0.6.1
#  + sng4onnx==2.0.1
#  - tensorboard==2.20.0
#  + tensorboard==2.19.0
#  - tensorflow==2.20.0
#  + tensorflow==2.19.1
#  - tf-keras==2.20.0
#  + tf-keras==2.19.0
#
# requirements: AutoUpdate success ✅ 24.2s
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
#
#
# TensorFlow SavedModel: starting export with tensorflow 2.20.0...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/calibration_image_sample_data_20x128x128x3_float32.npy.zip to 'calibration_image_sample_data_20x128x128x3_float32.npy.zip': 100% ━━━━━━━━━━━━ 1.1MB 36.3MB/s 0.0s
# Unzipping calibration_image_sample_data_20x128x128x3_float32.npy.zip to /content/calibration_image_sample_data_20x128x128x3_float32.npy...: 100% ━━━━━━━━━━━━ 1/1 28.6files/s 0.0s
# TensorFlow SavedModel: starting TFLite export with onnx2tf 1.28.8...
# Saved artifact at '/content/best_saved_model'. The following endpoints are available:
#
# * Endpoint 'serving_default'
#   inputs_0 (POSITIONAL_ONLY): TensorSpec(shape=(1, 640, 640, 3), dtype=tf.float32, name='images')
# Output Type:
#   TensorSpec(shape=(1, 5, 8400), dtype=tf.float32, name=None)
# Captures:
#   140510635253328: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   140510635251792: TensorSpec(shape=(3, 3, 3, 16), dtype=tf.float32, name=None)
#   140510635252560: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   140510635256208: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   140510635257744: TensorSpec(shape=(3, 3, 16, 32), dtype=tf.float32, name=None)
#   140510635257360: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   140510635257936: TensorSpec(shape=(1, 1, 32, 32), dtype=tf.float32, name=None)
#   140510635258128: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   140510635246800: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140510635258704: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140510635260624: TensorSpec(shape=(3, 3, 16, 16), dtype=tf.float32, name=None)
#   140510635261008: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   140510635259088: TensorSpec(shape=(3, 3, 16, 16), dtype=tf.float32, name=None)
#   140510635259856: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   140510635254864: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140510635259664: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140510635261200: TensorSpec(shape=(1, 1, 48, 32), dtype=tf.float32, name=None)
#   140510635261392: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   140510635258512: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   140510635260432: TensorSpec(shape=(3, 3, 32, 64), dtype=tf.float32, name=None)
#   140510635261584: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140510635261776: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   140510635049040: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140510635049808: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140510635049616: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140510635051728: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   140510635051920: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   140510635049232: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   140510635049424: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   140510635051152: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   140510635052112: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   140510635050768: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   140510635052496: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   140510635050000: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140510635050192: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140510635052880: TensorSpec(shape=(1, 1, 128, 64), dtype=tf.float32, name=None)
#   140510635052304: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140510635053072: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   140510635051344: TensorSpec(shape=(3, 3, 64, 128), dtype=tf.float32, name=None)
#   140510635052688: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   140510635053456: TensorSpec(shape=(1, 1, 128, 128), dtype=tf.float32, name=None)
#   140510635053648: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   140510635054224: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140510635054032: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140510635056144: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   140510635056336: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140510635053840: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   140510635053264: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140510635055568: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   140510635056528: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140510635055184: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   140510635056912: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140510635054416: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140510635054608: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140510635057296: TensorSpec(shape=(1, 1, 256, 128), dtype=tf.float32, name=None)
#   140510635056720: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   140510635057488: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   140510635055760: TensorSpec(shape=(3, 3, 128, 256), dtype=tf.float32, name=None)
#   140510635057104: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   140510635057872: TensorSpec(shape=(1, 1, 256, 256), dtype=tf.float32, name=None)
#   140510635058064: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   140510635058640: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140510635058448: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140510635060560: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   140510635060752: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   140510635058256: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   140510635057680: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   140510635058832: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140510635059024: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140510635060944: TensorSpec(shape=(1, 1, 384, 256), dtype=tf.float32, name=None)
#   140510635059600: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   140510635059984: TensorSpec(shape=(1, 1, 256, 128), dtype=tf.float32, name=None)
#   140510635061328: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   140510635061520: TensorSpec(shape=(1, 1, 512, 256), dtype=tf.float32, name=None)
#   140510635061712: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   140510635062096: TensorSpec(shape=(1, 1, 384, 128), dtype=tf.float32, name=None)
#   140510635062288: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   140510635062672: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140510635061904: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140510635064016: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   140510635064208: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140510635062480: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   140510635060176: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140510635063440: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140510635061136: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140510635064976: TensorSpec(shape=(1, 1, 192, 128), dtype=tf.float32, name=None)
#   140510635064784: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   140510635063632: TensorSpec(shape=(1, 1, 192, 64), dtype=tf.float32, name=None)
#   140510635063824: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140510595088656: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140510595088464: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140510635065168: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   140510635063248: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   140510595090576: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   140510595090000: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   140510595088848: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140510595089040: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140510595091152: TensorSpec(shape=(1, 1, 96, 64), dtype=tf.float32, name=None)
#   140510595090960: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140510595091344: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   140510595089616: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   140510595090768: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140510595093264: TensorSpec(shape=(1, 1, 192, 128), dtype=tf.float32, name=None)
#   140510595092688: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   140510595094224: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140510595093840: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140510595096144: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   140510595094608: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140510595096912: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   140510595096528: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140510595094800: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140510595094992: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140510595097872: TensorSpec(shape=(1, 1, 192, 128), dtype=tf.float32, name=None)
#   140510595097680: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   140510595098448: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   140510595097104: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   140510595094416: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   140510595097296: TensorSpec(shape=(1, 1, 384, 256), dtype=tf.float32, name=None)
#   140510595098832: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   140510595100176: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140510595099024: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140510595100368: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   140510595102672: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   140510595103632: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   140510595103440: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   140510595100944: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140510595101328: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140510595101712: TensorSpec(shape=(1, 1, 384, 256), dtype=tf.float32, name=None)
#   140510595102480: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   140510595100752: TensorSpec(shape=(3, 3, 256, 64), dtype=tf.float32, name=None)
#   140510595095568: TensorSpec(shape=(3, 3, 128, 64), dtype=tf.float32, name=None)
#   140510595091728: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   140510595101520: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140510595096720: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140510595091536: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140510595102864: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   140510595097488: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   140510595091920: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   140510595104016: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140510595098640: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140510595092304: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140510595104400: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   140510595099792: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   140510595093648: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   140510595104592: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140510595099600: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140510595093072: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140510595102096: TensorSpec(shape=(3, 3, 256, 64), dtype=tf.float32, name=None)
#   140510595098064: TensorSpec(shape=(3, 3, 128, 64), dtype=tf.float32, name=None)
#   140510595092112: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   140510595103056: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140510595095952: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140510595090192: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140510595104208: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   140510595099216: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   140510595092880: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   140510595103824: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140510595098256: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140510595092496: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140510465541712: TensorSpec(shape=(1, 1, 16, 1), dtype=tf.float32, name=None)
#   140510595103248: TensorSpec(shape=(1, 1, 64, 1), dtype=tf.float32, name=None)
#   140510595100560: TensorSpec(shape=(1, 1, 64, 1), dtype=tf.float32, name=None)
#   140510595094032: TensorSpec(shape=(1, 1, 64, 1), dtype=tf.float32, name=None)
#   140510465540176: TensorSpec(shape=(1,), dtype=tf.float32, name=None)
#   140510595099408: TensorSpec(shape=(1,), dtype=tf.float32, name=None)
#   140510595093456: TensorSpec(shape=(1,), dtype=tf.float32, name=None)
#   140510465541904: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   140510465542096: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   140510465541136: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   140510465543056: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   140510465542480: TensorSpec(shape=(1, 2, 8400), dtype=tf.float32, name=None)
#   140510465542672: TensorSpec(shape=(1, 2, 8400), dtype=tf.float32, name=None)
# TensorFlow SavedModel: export success ✅ 46.7s, saved as '/content/best_saved_model' (29.5 MB)
#
# TensorFlow Lite: starting export with tensorflow 2.20.0...
# TensorFlow Lite: export success ✅ 0.0s, saved as '/content/best_saved_model/best_float32.tflite' (11.7 MB)
#
# Export complete (47.4s)
# Results saved to /content/best_saved_model/best_float32.tflite
# Predict:         yolo predict task=detect model=/content/best_saved_model/best_float32.tflite imgsz=640
# Validate:        yolo val task=detect model=/content/best_saved_model/best_float32.tflite imgsz=640 data=/content/Indian-License-Plate-1/data.yaml
# Visualize:       https://netron.app
# Export Complete
